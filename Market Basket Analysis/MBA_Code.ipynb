# %%
# Import packages
import pandas as pd
import numpy as np
import datetime as dt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# # Reading and merging tables

# %%
# Import order product dataset
df = pd.read_csv('order_products.csv', usecols=['order_id', 'product_id'])
df.head()
# Out:
#    order_id  product_id
# 0        10          24
# 1        10          83
# 2        10          16
# 3        10          24
# 4        10          83

# %%
#check for null values
df.isnull().sum()
# Out:
# order_id      0
# product_id    0
# dtype: int64

# %%
# Import product label mapping
products = pd.read_csv('products.csv')
products.head()
# Out:
#    product_id  department_id                product_name
# 0          61             19               cookies cakes
# 1         104             13           spices seasonings
# 2          94              7                         tea
# 3          38              1                frozen meals
# 4           5             13  marinades meat preparation

# %%
#check for null values
products.isnull().sum()
# Out:
# product_id       0
# department_id    0
# product_name     0
# dtype: int64

# %%
# Merge product labels
df = pd.merge(df, products, how='left', on='product_id').\
    drop(["product_id", "department_id"], axis=1)
df.head()
# Out:
#    order_id      product_name
# 0        10      fresh fruits
# 1        10  fresh vegetables
# 2        10       fresh herbs
# 3        10      fresh fruits
# 4        10  fresh vegetables

# %%
# Merge product labels
df = pd.merge(df, products, how='left', on='product_id').\
    drop(["product_id", "department_id"], axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-59a63ad3ec1c> in <module>
#       1 # Merge product labels
# ----> 2 df = pd.merge(df, products, how='left', on='product_id').\
#       3     drop(["product_id", "department_id"], axis=1)
#       4 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
#     654         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1016                         right_keys.append(rk)
#    1017                     if lk is not None:
# -> 1018                         left_keys.append(left._get_label_or_level_values(lk))
#    1019                         join_names.append(lk)
#    1020                     else:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
#    1564
#    1565         # Check for duplicates
#
# KeyError: 'product_id'

# %% [markdown]
# # Data exploration

# %%
# how many departments
products['department_id'].unique()
# Out:
# array([19, 13,  7,  1, 11, 16, 17, 18, 12,  9,  8, 14, 15,  4, 21,  6, 20,
#         5,  3,  2, 10], dtype=int64)

# %%
#check the average amount of items per order
count_df = df.groupby('order_id').agg(['count'])
total_orders = len(count_df)
mean_number_item_perorder=count_df['product_name']['count'].sum()/total_orders
mean_number_item_perorder
# Out:
# 10.097505

# %%
# Get modes and unique values
df.astype(object).describe()
# Out:
#         order_id  product_name
# count    2019501       2019501
# unique    200000           134
# top       790903  fresh fruits
# freq         137        226039

# %%
# Check product frequencies
df['product_name'].value_counts().head(20)
# Out:
# fresh fruits                     226039
# fresh vegetables                 212611
# packaged vegetables fruits       109596
# yogurt                            90751
# packaged cheese                   61502
# milk                              55150
# water seltzer sparkling water     52564
# chips pretzels                    45306
# soy lactosefree                   39389
# bread                             36381
# refrigerated                      35893
# frozen produce                    32432
# ice cream ice                     31323
# energy granola bars               28639
# crackers                          28574
# eggs                              27986
# lunch meat                        24470
# frozen meals                      24449
# cereal                            23754
# baby food formula                 23355
# Name: product_name, dtype: int64

# %%
# Pivot the data - lines as orders and products as columns
pt = pd.pivot_table(df, index='order_id', columns='product_name', 
                    aggfunc=lambda x: 1 if len(x)>0 else 0).fillna(0)
pt.head()
# Out:
# product_name  air fresheners candles  asian foods  baby accessories  \
# order_id
# 10                               0.0          0.0               0.0
# 11                               0.0          0.0               0.0
# 28                               0.0          0.0               0.0
# 38                               0.0          0.0               0.0
# 56                               0.0          0.0               0.0
#
# product_name  baby bath body care  baby food formula  bakery desserts  \
# order_id
# 10                            0.0                1.0              0.0
# 11                            0.0                0.0              0.0
# 28                            0.0                0.0              0.0
# 38                            0.0                0.0              0.0
# 56                            0.0                0.0              0.0
#
# product_name  baking ingredients  baking supplies decor  beauty  \
# order_id
# 10                           0.0                    0.0     0.0
# 11                           0.0                    0.0     0.0
# 28                           0.0                    0.0     0.0
# 38                           0.0                    0.0     0.0
# 56                           0.0                    0.0     0.0
#
# product_name  beers coolers  ...  spreads  tea  tofu meat alternatives  \
# order_id                     ...
# 10                      0.0  ...      0.0  0.0                     0.0
# 11                      0.0  ...      0.0  0.0                     0.0
# 28                      0.0  ...      1.0  0.0                     0.0
# 38                      0.0  ...      0.0  0.0                     0.0
# 56                      0.0  ...      0.0  0.0                     0.0
#
# product_name  tortillas flat bread  trail mix snack mix  trash bags liners  \
# order_id
# 10                             0.0                  0.0                0.0
# 11                             0.0                  0.0                0.0
# 28                             0.0                  0.0                0.0
# 38                             0.0                  0.0                0.0
# 56                             0.0                  0.0                0.0
#
# product_name  vitamins supplements  water seltzer sparkling water  \
# order_id
# 10                             0.0                            0.0
# 11                             0.0                            0.0
# 28                             0.0                            0.0
# 38                             0.0                            0.0
# 56                             0.0                            0.0
#
# product_name  white wines  yogurt
# order_id
# 10                    0.0     0.0
# 11                    0.0     0.0
# 28                    0.0     1.0
# 38                    0.0     0.0
# 56                    0.0     0.0
#
# [5 rows x 134 columns]

# %%
# Check in how many orders was product fresh fruits sold
pt['fresh fruits'].sum() # more than 55%
# Out:
# 111199.0

# %%
# Check in how many orders was product yogurt sold
pt['yogurt'].sum()
# Out:
# 52735.0

# %%
pt['milk'].sum()
# Out:
# 48665.0

# %%
pt['fresh vegetables'].sum()
# Out:
# 88872.0

# %% [markdown]
# # Creating association rules 5% support

# %%
# Apply the APRIORI algorithm to get frequent itemsets
# Rules supported in at least 5% of the transactions 
frequent_itemsets = apriori(pt, min_support=0.05, use_colnames=True)

# %%
frequent_itemsets
# Out:
#       support                                           itemsets
# 0    0.076635                               (baking ingredients)
# 1    0.163865                                            (bread)
# 2    0.067765                                 (breakfast bakery)
# 3    0.074330                                           (butter)
# 4    0.069305                                  (candy chocolate)
# ..        ...                                                ...
# 151  0.051295         (yogurt, milk, packaged vegetables fruits)
# 152  0.051915  (yogurt, packaged cheese, packaged vegetables ...
# 153  0.062535  (milk, fresh vegetables, fresh fruits, package...
# 154  0.068325  (packaged cheese, fresh vegetables, fresh frui...
# 155  0.076240  (yogurt, fresh vegetables, fresh fruits, packa...
#
# [156 rows x 2 columns]

# %%
# Generate the association rules - by confidence
rulesConfidence = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.60)
rulesConfidence.sort_values(by='confidence', ascending=False, inplace=True)
rulesConfidence.head()
# Out:
#                                           antecedents         consequents  \
# 17                        (fresh fruits, fresh herbs)  (fresh vegetables)
# 41  (yogurt, fresh vegetables, packaged vegetables...      (fresh fruits)
# 37  (fresh vegetables, milk, packaged vegetables f...      (fresh fruits)
# 8                                       (fresh herbs)  (fresh vegetables)
# 39  (packaged cheese, fresh vegetables, packaged v...      (fresh fruits)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 17            0.070135            0.444360  0.061815    0.881372  1.983463
# 41            0.087995            0.555995  0.076240    0.866413  1.558311
# 37            0.073075            0.555995  0.062535    0.855765  1.539159
# 8             0.093005            0.444360  0.078655    0.845707  1.903203
# 39            0.081970            0.555995  0.068325    0.833537  1.499180
#
#     leverage  conviction
# 17  0.030650    4.683872
# 41  0.027315    3.323711
# 37  0.021906    3.078336
# 8   0.037327    3.601205
# 39  0.022750    2.667284

# %%
# Generate the association rules - by lift
rulesLift = association_rules(frequent_itemsets, metric="lift", min_threshold=0)
rulesLift.sort_values(by='lift', ascending=True, inplace=True)
rulesLift.head()
# Out:
#                           antecedents                       consequents  \
# 110   (water seltzer sparkling water)                (fresh vegetables)
# 111                (fresh vegetables)   (water seltzer sparkling water)
# 232  (fresh vegetables, fresh fruits)   (water seltzer sparkling water)
# 233   (water seltzer sparkling water)  (fresh vegetables, fresh fruits)
# 82    (water seltzer sparkling water)                    (fresh fruits)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 110            0.193005            0.444360  0.083355    0.431880  0.971915
# 111            0.444360            0.193005  0.083355    0.187584  0.971915
# 232            0.317560            0.193005  0.063235    0.199128  1.031723
# 233            0.193005            0.317560  0.063235    0.327634  1.031723
# 82             0.193005            0.555995  0.111045    0.575348  1.034807
#
#      leverage  conviction
# 110 -0.002409    0.978033
# 111 -0.002409    0.993328
# 232  0.001944    1.007645
# 233  0.001944    1.014983
# 82   0.003735    1.045573

# %% [markdown]
# # Creating association rules 2.5% support

# %%
# Apply the APRIORI algorithm to get frequent itemsets
# Rules supported in at least 2.5% of the transactions 
frequent_itemsets = apriori(pt, min_support=0.025, use_colnames=True)

# %%
# Generate the association rules - by confidence
rulesConfidence = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
rulesConfidence.sort_values(by='confidence', ascending=True, inplace=True)
rulesConfidence.head(50)
# Out:
#                                            antecedents  \
# 172  (chips pretzels, fresh fruits, packaged vegeta...
# 158             (packaged cheese, fresh fruits, bread)
# 207            (yogurt, packaged cheese, fresh fruits)
# 179                         (eggs, fresh fruits, milk)
# 15                                 (spices seasonings)
# 4                               (fresh dips tapenades)
# 230  (yogurt, packaged cheese, fresh vegetables, fr...
# 8                           (hot cereal pancake mixes)
# 151           (packaged vegetables fruits, lunch meat)
# 205   (packaged cheese, fresh fruits, soy lactosefree)
#
#                       consequents  antecedent support  consequent support  \
# 172            (fresh vegetables)            0.057595            0.444360
# 158            (fresh vegetables)            0.044665            0.444360
# 207            (fresh vegetables)            0.070020            0.444360
# 179            (fresh vegetables)            0.036475            0.444360
# 15             (fresh vegetables)            0.052165            0.444360
# 4                  (fresh fruits)            0.098205            0.555995
# 230  (packaged vegetables fruits)            0.049105            0.365415
# 8                  (fresh fruits)            0.045025            0.555995
# 151            (fresh vegetables)            0.053225            0.444360
# 205            (fresh vegetables)            0.036390            0.444360
#
#       support  confidence      lift  leverage  conviction
# 172  0.040325    0.700148  1.575631  0.014732    1.853045
# 158  0.031275    0.700213  1.575778  0.011428    1.853447
# 207  0.049105    0.701300  1.578224  0.017991    1.860192
# 179  0.025580    0.701302  1.578230  0.009372    1.860208
# 15   0.036660    0.702770  1.581533  0.013480    1.869394
# 4    0.069040    0.703019  1.264434  0.014439    1.495063
# 230  0.034565    0.703900  1.926302  0.016621    2.143143
# 8    0.031740    0.704942  1.267892  0.006706    1.504804
# 151  0.037600    0.706435  1.589781  0.013949    1.892732
# 205  0.025735    0.707200  1.591502  0.009565    1.897676

# %%
# Generate the association rules - by lift
rulesLift = association_rules(frequent_itemsets, metric="lift", min_threshold=1.5)
rulesLift.sort_values(by='lift', ascending=True, inplace=True)
rulesLift.head(50)
# Out:
#                                            antecedents  \
# 318                                     (fresh fruits)
# 317  (energy granola bars, packaged vegetables fruits)
# 808                     (eggs, fresh vegetables, milk)
# 821                                     (fresh fruits)
# 220                           (fresh fruits, crackers)
# 221                                             (milk)
# 626  (fresh vegetables, fresh fruits, packaged vege...
# 639                                            (bread)
# 27                                            (cereal)
# 26                                            (yogurt)
#
#                                            consequents  antecedent support  \
# 318  (energy granola bars, packaged vegetables fruits)            0.555995
# 317                                     (fresh fruits)            0.039500
# 808                                     (fresh fruits)            0.030660
# 821                     (eggs, fresh vegetables, milk)            0.555995
# 220                                             (milk)            0.075480
# 221                           (fresh fruits, crackers)            0.243325
# 626                                            (bread)            0.186580
# 639  (fresh vegetables, fresh fruits, packaged vege...            0.163865
# 27                                            (yogurt)            0.092560
# 26                                            (cereal)            0.263675
#
#      consequent support   support  confidence      lift  leverage  conviction
# 318            0.039500  0.032945    0.059254  1.500105  0.010983    1.020998
# 317            0.555995  0.032945    0.834051  1.500105  0.010983    2.675545
# 808            0.555995  0.025580    0.834312  1.500574  0.008533    2.679762
# 821            0.030660  0.025580    0.046008  1.500574  0.008533    1.016088
# 220            0.243325  0.027570    0.365262  1.501129  0.009204    1.192107
# 221            0.075480  0.027570    0.113305  1.501129  0.009204    1.042659
# 626            0.163865  0.045910    0.246061  1.501606  0.015336    1.109022
# 639            0.186580  0.045910    0.280170  1.501606  0.015336    1.130016
# 27             0.263675  0.036675    0.396229  1.502719  0.012269    1.219544
# 26             0.092560  0.036675    0.139092  1.502719  0.012269    1.054050

# %%
# Add a column with the length
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

# Length=2 and Support>=0.2
frequent_itemsets[(frequent_itemsets['length'] == 2) & (frequent_itemsets['support'] >= 0.2)]
# Out:
#       support                                        itemsets  length
# 180  0.317560                (fresh vegetables, fresh fruits)       2
# 200  0.269870      (fresh fruits, packaged vegetables fruits)       2
# 236  0.234555  (fresh vegetables, packaged vegetables fruits)       2

# %% [markdown]
# # Complementary Products

# %%
# High Confidence and high Lift 
rulesConfidence[(rulesConfidence['confidence'] >= 0.6) & (rulesConfidence['lift'] >= 1.6)]
# Out:
#                                            antecedents         consequents  \
# 172  (chips pretzels, fresh fruits, packaged vegeta...  (fresh vegetables)
# 158             (packaged cheese, fresh fruits, bread)  (fresh vegetables)
# 207            (yogurt, packaged cheese, fresh fruits)  (fresh vegetables)
# 179                         (eggs, fresh fruits, milk)  (fresh vegetables)
# 15                                 (spices seasonings)  (fresh vegetables)
# ..                                                 ...                 ...
# 226  (packaged cheese, fresh vegetables, milk, pack...      (fresh fruits)
# 146          (packaged vegetables fruits, fresh herbs)  (fresh vegetables)
# 231  (yogurt, packaged cheese, fresh vegetables, pa...      (fresh fruits)
# 228  (yogurt, fresh vegetables, milk, packaged vege...      (fresh fruits)
# 190  (fresh herbs, fresh fruits, packaged vegetable...  (fresh vegetables)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 172            0.057595            0.444360  0.040325    0.700148  1.575631
# 158            0.044665            0.444360  0.031275    0.700213  1.575778
# 207            0.070020            0.444360  0.049105    0.701300  1.578224
# 179            0.036475            0.444360  0.025580    0.701302  1.578230
# 15             0.052165            0.444360  0.036660    0.702770  1.581533
# ..                  ...                 ...       ...         ...       ...
# 226            0.032215            0.555995  0.028555    0.886388  1.594238
# 146            0.052535            0.444360  0.046980    0.894261  2.012470
# 231            0.038635            0.555995  0.034565    0.894655  1.609106
# 228            0.036455            0.555995  0.032845    0.900974  1.620471
# 190            0.043490            0.444360  0.039660    0.911934  2.052241
#
#      leverage  conviction
# 172  0.014732    1.853045
# 158  0.011428    1.853447
# 207  0.017991    1.860192
# 179  0.009372    1.860208
# 15   0.013480    1.869394
# ..        ...         ...
# 226  0.010644    3.908093
# 146  0.023636    5.254824
# 231  0.013084    4.214775
# 228  0.012576    4.483713
# 190  0.020335    6.309343
#
# [104 rows x 9 columns]

# %% [markdown]
# # Substitute Products

# %%
rulesLift2 = association_rules(frequent_itemsets, metric="lift", min_threshold=0.0)
rulesLift2.sort_values(by='lift', ascending=True, inplace=True)
rulesLift2.head(10)
# Out:
#             antecedents         consequents  antecedent support  \
# 345  (fresh vegetables)       (soft drinks)            0.444360
# 344       (soft drinks)  (fresh vegetables)            0.087310
# 275      (fresh fruits)       (soft drinks)            0.555995
# 274       (soft drinks)      (fresh fruits)            0.087310
# 265       (paper goods)      (fresh fruits)            0.063575
# 264      (fresh fruits)       (paper goods)            0.555995
# 67   (fresh vegetables)   (candy chocolate)            0.444360
# 66    (candy chocolate)  (fresh vegetables)            0.069305
# 336  (fresh vegetables)       (paper goods)            0.444360
# 337       (paper goods)  (fresh vegetables)            0.063575
#
#      consequent support   support  confidence      lift  leverage  conviction
# 345            0.087310  0.027845    0.062663  0.717709 -0.010952    0.973705
# 344            0.444360  0.027845    0.318921  0.717709 -0.010952    0.815823
# 275            0.087310  0.039585    0.071197  0.815447 -0.008959    0.982652
# 274            0.555995  0.039585    0.453384  0.815447 -0.008959    0.812280
# 265            0.555995  0.032090    0.504758  0.907847 -0.003257    0.896542
# 264            0.063575  0.032090    0.057716  0.907847 -0.003257    0.993782
# 67             0.069305  0.028210    0.063485  0.916017 -0.002586    0.993785
# 66             0.444360  0.028210    0.407041  0.916017 -0.002586    0.937064
# 336            0.063575  0.025885    0.058252  0.916277 -0.002365    0.994348
# 337            0.444360  0.025885    0.407157  0.916277 -0.002365    0.937246

# %% [markdown]
# # Checking the department of different products

# %%
print(products[products['product_name']  == 'fresh fruits'])
print(products[products['product_name']  == 'fresh vegetables'])
print(products[products['product_name']  == 'packaged vegetables fruits'])
# Out:
#     product_id  department_id  product_name
# 81          24              4  fresh fruits
#     product_id  department_id      product_name
# 35          83              4  fresh vegetables
#     product_id  department_id                product_name
# 27         123              4  packaged vegetables fruits

# %%
print(products[products['product_name']  == 'yogurt'])
print(products[products['product_name']  == 'packaged cheese'])
print(products[products['product_name']  == 'milk'])
# Out:
#    product_id  department_id product_name
# 8         120             16       yogurt
#     product_id  department_id     product_name
# 72          21             16  packaged cheese
#      product_id  department_id product_name
# 108          84             16         milk

# %%
print(products[products['product_name']  == 'soft drinks'])
# Out:
#     product_id  department_id product_name
# 54          77              7  soft drinks

# %%
print(products[products['product_name']  == 'candy chocolate'])
# Out:
#     product_id  department_id     product_name
# 74          45             19  candy chocolate

# %%
print(products[products['product_name']  == 'paper goods'])
# Out:
#      product_id  department_id product_name
# 123          54             17  paper goods
